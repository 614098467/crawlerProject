# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification
import shap

# %%
# 创建三分类数据集
X, y = make_classification(
    n_samples=1000,       # 样本数
    n_features=10,        # 特征数
    n_informative=5,      # 有信息量的特征
    n_classes=3,          # 分类数
    random_state=42
)

# 拆分训练集和测试集
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 转为 DataFrame 以便展示
feature_names = [f"Feature {i}" for i in range(X.shape[1])]
X_train = pd.DataFrame(X_train, columns=feature_names)
X_test = pd.DataFrame(X_test, columns=feature_names)

# %%
# 创建随机森林分类器
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# 创建 SHAP explainer
explainer = shap.TreeExplainer(clf)

# 计算 SHAP 值
shap_values = explainer.shap_values(X_test)

print(shap_values.shape)

# 打印 SHAP 值的形状（每个类别的 SHAP 值）
print([sv.shape for sv in shap_values])

print(shap_values[:,:,0].shape)
# Out:
# (300, 10, 3)
# [(10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3), (10, 3)]
# (300, 10)

# %%
# 选择第一个类别进行分析
shap.summary_plot(shap_values[:,:,2], X_test, plot_type="bar", class_names=clf.classes_)

# %%
for i, class_name in enumerate(clf.classes_):
    print(f"SHAP for class {class_name}")
    shap.summary_plot(shap_values[:,:,i], X_test)
# Out:
# SHAP for class 0
# SHAP for class 1
# SHAP for class 2

# %%
shap_values2 = explainer(X_test)
shap.plots.bar(shap_values2[0,:,1],show_data = True)

# %%
print(feature_names)
shap.dependence_plot('Feature 1',shap_values[:,:,0], X_test)
# Out:
# ['Feature 0', 'Feature 1', 'Feature 2', 'Feature 3', 'Feature 4', 'Feature 5', 'Feature 6', 'Feature 7', 'Feature 8', 'Feature 9']

# %%
shap.plots.heatmap(shap_values2)
# Out:
# ---------------------------------------------------------------------------
# DimensionError                            Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 shap.plots.heatmap(shap_values2)
#
# File ~/anaconda3/lib/python3.10/site-packages/shap/plots/_heatmap.py:78, in heatmap(shap_values, instance_order, feature_values, feature_order, max_display, cmap, show, plot_width, ax)
#      76     raise Exception(f"Unsupported feature_order: {str(feature_order)}!")
#      77 xlabel = "Instances"
# ---> 78 instance_order = convert_ordering(instance_order, shap_values)
#      79 # if issubclass(type(instance_order), OpChain):
#      80 #     #xlabel += " " + instance_order.summary_string("SHAP values")
#      81 #     instance_order = instance_order.apply(Explanation(values))
#    (...)
#      84 # else:
#      85 #     instance_order_ops = None
#      87 feature_names = np.array(shap_values.feature_names)[feature_order]
#
# File ~/anaconda3/lib/python3.10/site-packages/shap/plots/_utils.py:23, in convert_ordering(ordering, shap_values)
#      21 def convert_ordering(ordering, shap_values):
#      22     if issubclass(type(ordering), OpChain):
# ---> 23         ordering = ordering.apply(Explanation(shap_values))
#      24     if issubclass(type(ordering), Explanation):
#      25         if "argsort" in [op["name"] for op in ordering.op_history]:
#
# File ~/anaconda3/lib/python3.10/site-packages/shap/utils/_general.py:278, in OpChain.apply(self, obj)
#     276 op,args,kwargs = o
#     277 if args is not None:
# --> 278     obj = getattr(obj, op)(*args, **kwargs)
#     279 else:
#     280     obj = getattr(obj, op)
#
# File ~/anaconda3/lib/python3.10/site-packages/shap/_explanation.py:606, in Explanation.hclust(self, metric, axis)
#     603 values = self.values
#     605 if len(values.shape) != 2:
# --> 606     raise DimensionError("The hclust order only supports 2D arrays right now!")
#     608 if axis == 1:
#     609     values = values.T
#
# DimensionError: The hclust order only supports 2D arrays right now!
